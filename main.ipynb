# %% [markdown]
# # Clinically Structured and Graph-Based Feature Construction for Predicting 30-Day Diabetes Inpatient Readmission
# This is the main entry point for our code.
#
# [include some notes here on where to look but most of it shoudl be in the README]

# %% [markdown]
# ## Configuration

# %%
# imports
from Preprocessing.data_loading import read_data

# constants
FILENAME = 'diabetes_stratified'
FOLDER = 'Stratified'

# %% [markdown]
# ## Load cleaned dataset

# %%
df_fold = read_data(FILENAME, FOLDER)
